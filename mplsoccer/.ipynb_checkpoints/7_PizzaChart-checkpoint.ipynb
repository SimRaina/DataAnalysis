# %% [markdown]
# # 📊 Football Visualizations using `mplsoccer`
# This notebook demonstrates how to create Pizza Plot

# %%
from urllib.request import urlopen
import matplotlib.pyplot as plt
import pandas as pd

from mplsoccer import PyPizza, add_image, FontManager

# %%
# ---- LOAD DATA ----
df = pd.read_csv("EPL_AllPlayers_Perf_25_26_Till_GW10.csv")

# %%
# Select player
player = df[df['Player'].str.contains("Dijk", case=False, na=False)]

# ---- SELECT METRICS FOR Pizza plot ----
metrics = ['Gls', 'Sh', 'Dist', 'xG', 'npxG', 'npxG/Sh']

# %%
# Compute percentiles for each metric
for m in metrics:
    df[m + "_pct"] = df[m].rank(pct=True) * 100

van_dijk_percentiles = player[[m + "_pct" for m in metrics]]
van_dijk_percentiles
# Out:
#        Gls_pct     Sh_pct   Dist_pct     xG_pct   npxG_pct  npxG/Sh_pct
# 122  66.138614  39.306931  29.879518  42.376238  42.574257    52.650602

# %%
font_normal = FontManager('https://raw.githubusercontent.com/googlefonts/roboto/main/'
                          'src/hinted/Roboto-Regular.ttf')

# %%
# instantiate PyPizza class
baker = PyPizza(
    params=metrics,                  # list of parameters
    straight_line_color="#000000",  # color for straight lines
    straight_line_lw=1,             # linewidth for straight lines
    last_circle_lw=1,               # linewidth of last circle
    other_circle_lw=1,              # linewidth for other circles
    other_circle_ls="-."            # linestyle for other circles
)

# %%
# plot pizza
fig, ax = baker.make_pizza(
    van_dijk_percentiles,              # list of values
    figsize=(8, 8),      # adjust figsize according to your need
    param_location=110,  # where the parameters will be added
    kwargs_slices=dict(
        facecolor="cornflowerblue", edgecolor="#000000",
        zorder=2, linewidth=1
    ),                   # values to be used when plotting slices
    kwargs_params=dict(
        color="#000000", fontsize=12,
        fontproperties=font_normal.prop, va="center"
    ),                   # values to be used when adding parameter
    kwargs_values=dict(
        color="#000000", fontsize=12,
        fontproperties=font_normal.prop, zorder=3,
        bbox=dict(
            edgecolor="#000000", facecolor="cornflowerblue",
            boxstyle="round,pad=0.2", lw=1
        )
    )                    # values to be used when adding parameter-values
)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 # plot pizza
# ----> 2 fig, ax = baker.make_pizza(
#       3     van_dijk_percentiles,              # list of values
#       4     figsize=(8, 8),      # adjust figsize according to your need
#       5     param_location=110,  # where the parameters will be added
#       6     kwargs_slices=dict(
#       7         facecolor="cornflowerblue", edgecolor="#000000",
#       8         zorder=2, linewidth=1
#       9     ),                   # values to be used when plotting slices
#      10     kwargs_params=dict(
#      11         color="#000000", fontsize=12,
#      12         fontproperties=font_normal.prop, va="center"
#      13     ),                   # values to be used when adding parameter
#      14     kwargs_values=dict(
#      15         color="#000000", fontsize=12,
# ...
