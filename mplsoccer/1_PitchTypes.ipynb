# %%
from mplsoccer import Pitch, VerticalPitch
import matplotlib.pyplot as plt

# %%
pitch = Pitch(pitch_color='grass', line_color='white', stripe=True)
# specifying figure size (width, height)
fig,ax = pitch.draw(figsize=(4, 2))

# %%
pitch = VerticalPitch(pitch_color='grass', line_color='white', half=True, stripe=True)
fig,ax = pitch.draw(figsize=(4, 2))

# %%
#pitch_type argument: ‘statsbomb’, ‘opta’, ‘tracab’, ‘wyscout’, 
# ‘uefa’, ‘metricasports’, ‘custom’, ‘skillcorner’, ‘secondspectrum’ and ‘impect’. 
pitch = Pitch(pitch_type='tracab',  # example plotting a tracab pitch
              pitch_color='grass',
              pitch_length=105, pitch_width=68,
              axis=True, label=True)  # showing axis labels is optional
fig, ax = pitch.draw()

# %%
pitch = Pitch(pitch_type='opta', pitch_color='grass')
fig,axs = pitch.grid(nrows = 1, ncols = 2)

# %%
# matplotlib + mplsoccer (same axes)
fig, axs = plt.subplots(nrows=1, ncols=2)
pitch = Pitch(pitch_color='grass')
pie = axs[0].pie(x=[5, 20])
pitch.draw(ax=axs[1])

# %%
pitch = Pitch(pitch_color='#aabb97', line_color='white',
              stripe_color='#c2d59d', stripe=True)
fig, ax = pitch.draw()

# %%
pitch = Pitch(pitch_color='grass', linestyle='--', linewidth= 1, goal_linestyle='-')
fig, ax = pitch.draw(figsize=(4,2))

# %%
pitch = Pitch(line_alpha=0.5, goal_alpha=0.3)
fig, ax = pitch.draw(figsize=(4,2))

# %%
pitch = VerticalPitch(pitch_color='grass', corner_arcs=True, half=True)
fig, ax = pitch.draw(figsize=(8, 4))

# %%
pitch = Pitch(positional=True, shade_middle=True, 
              positional_color='#eadddd', 
               shade_color='#f2f2f2')
fig, ax = pitch.draw(figsize=(4,2))

# %%
fig, axs = plt.subplots(nrows=3, figsize=(6, 10))
pitch = Pitch(goal_type='box', goal_alpha=1)  # you can also adjust the transparency (alpha)
pitch.draw(axs[0])
pitch = Pitch(goal_type='line')
pitch.draw(axs[1])
pitch = Pitch(goal_type='circle', linewidth=1)
pitch.draw(axs[2])

# %%
pitch = Pitch(linewidth=3,
              # the size of the penalty and center spots relative to the pitch_length
              spot_scale=0.01)
fig, ax = pitch.draw(figsize=(4,2))

# %%
pitch = Pitch(axis=True, label=True, tick=True)
fig, ax = pitch.draw(figsize=(4,2))
