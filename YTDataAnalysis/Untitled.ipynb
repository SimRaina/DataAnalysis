# %%
import pandas as pd
import requests

# %%
standing_url = "https://www.premierleague.com/tables"

# %%
data = requests.get(standing_url)

# %%
data.text
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n    <meta name="twitter:title" content="Premier League Table, Form Guide & Season Archives"/>\n<meta name="keywords" content="Premier League, Football, Soccer, Official"/>\n<meta property="og:type" content="website"/>\n<meta name="description" content="View the latest Premier League tables, form guides and season archives, on the official website of the Premier League."/>\n<meta name="twitter:description" content="View the latest Premier League tables, form guides and season archives, on the official website of the Premier League."/>\n<meta name="twitter:image" content="https://s3.amazonaws.com/premierleague-static-files/premierleague/pl_icon.png"/>\n<meta property="og:title" content="Premier League Table, Form Guide & Season Archives"/>\n<meta property="og:image" content="https://s3.amazonaws.com/premierleague-static-files/premierleague/pl_icon.png"/>\n<meta name="theme-color" content="#38003C"/>\n<title>Premier League Table, Form Guide & 
# ...

# %%
matches = pd.read_html(data.text, match = "Position")

# %%
matches[0]
# Out:
#                                         Position  Pos  \
# 0                             1  Previous Position  1
# 1   Manchester City  Recent Result - Sunday 14 May...
# 2                             2  Previous Position  2
# 3   Arsenal  Recent Result - Saturday 20 May 2023 ...
# 4                             3  Previous Position  3
# 5   Newcastle United  Recent Result - Thursday 18 ...
# 6                             4  Previous Position  4
# 7   Manchester United  Recent Result - Saturday 20...
# 8                             5  Previous Position  5
# 9   Liverpool  Recent Result - Saturday 20 May 202...
# 10                            6  Previous Position  6
# 11  Brighton and Hove Albion  Recent Result - Thur...
# 12                            7  Previous Position  8
# 13  Aston Villa  Recent Result - Saturday 20 May 2...
# 14                            8  Previous Position  7
# 15  Tottenham Hotspur  Recent Result - Saturday 20...
# ...
